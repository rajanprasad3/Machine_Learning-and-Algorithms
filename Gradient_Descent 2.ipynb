# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [77.6541566]
# 1.490027456840085

# %%
m = 29.19

# %%
class GDRegressor:
    def __init__(self,learning_rate,epochs):
        self.m = 29.19
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
    def fit(self,X,y):
        # calculate the b using GD
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
gd = GDRegressor(0.01,10)

# %%
gd.fit(X,y)
# Out:
# -24303.74725426782 123.03747254267819
# 24303.747254267815 -119.99999999999997
# -24303.74725426781 123.03747254267816
# 24303.747254267804 -119.99999999999989
# -24303.747254267797 123.03747254267807
# 24303.74725426779 -119.99999999999983
# -24303.747254267782 123.03747254267799
# 24303.747254267775 -119.99999999999977
# -24303.747254267775 123.03747254267799
# 24303.747254267775 -119.99999999999977
# -119.99999999999977
