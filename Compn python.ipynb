# %%
print("hello")
# Out:
# hello

# %%
#Veriables
can="soda"

# %%
can
# Out:
# 'soda'

# %%
can="bins"

# %%
can
# Out:
# 'bins'

# %%
print(can)
# Out:
# bins

# %%
type(can)
# Out:
# str

# %%
pizza=100
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa=20.5
ice_cream=100

# %%
total = pizza + ice_cream + samosa
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
total > 200
# Out:
# True

# %%
above_threshold = total > 200
above_threshold
# Out:
# True

# %%
foo="jalebi"
foo
# Out:
# 'jalebi'

# %%
bar=foo
bar
# Out:
# 'jalebi'

# %%
#memory addres
id(foo)
# Out:
# 2112646304688

# %%
bar="samosa"
bar
# Out:
# 'samosa'

# %%
id(bar)
# Out:
# 2112644920400

# %%
foo
# Out:
# 'jalebi'

# %%
a = b = c = 100
print (a)
print (b)
print (c)
# Out:
# 100
# 100
# 100

# %%
a,b,c = 1,2,"zara ali"
print (a)
print (b)
print (c)
# Out:
# 1
# 2
# zara ali

# %%
a=100
b=200
c=150
print(a)
print(b)
print(c)
# Out:
# 100
# 200
# 150

# %%
a,b,c = (10,20,30)
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
print(a,b,c)
# Out:
# 10 20 30

# %%
NAME = "Rajan"
name = "RAJAN"
print(NAME)
print(name)
# Out:
# Rajan
# RAJAN

# %%
counter = 100
_count = 100
name1 = "zara"
name2 = "sona"
age = 20
zara_salary = 10000
print(counter,_count,name1,name2,age,zara_salary)
# Out:
# 100 100 zara sona 20 10000

# %%
counter = 100
count = 100
zara_salary = 10000
print(counter,count,zara_salary)
# Out:
# 100 100 10000

# %%
width=10
height=20
area=width*height
area
# Out:
# 200

# %%
length = 30 
bredth = 20
area = length*bredth
area
# Out:
# 600

# %%
l=2
b=3
perimeter=2*(l+b)
perimeter
# Out:
# 10

# %%
width = 10
height = 20
area = width*height
perimeter = 2*(width+height)
print("area =",area)
print("perimerter =",perimeter)
# Out:
# area = 200
# perimerter = 60

# %%
base = 10 
height = 10
area = (base*height)/2
area
# Out:
# 50.0

# %%
type(area)
# Out:
# float

# %%
#Numbers
x = 5
y = 2
x+y
# Out:
# 7

# %%
x/y
# Out:
# 2.5

# %%
x//y
# Out:
# 2

# %%
x, y
# Out:
# (5, 2)

# %%
x**y
# Out:
# 25

# %%
10+2*3
# Out:
# 16

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
bar=2.3e-3

# %%
1e-3
# Out:
# 0.001

# %%
bar
# Out:
# 0.0023

# %%
fafda = 5

# %%
fafda
# Out:
# 5

# %%
import math
x = 16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5, "b")
# Out:
# '101'

# %%
#String

# %%
first = "mohan"
last = "kumar"

# %%
type(first)
# Out:
# str

# %%
name = first + " " +last
name
# Out:
# 'mohan kumar'

# %%
name = f"{first} {last}"
name
# Out:
# 'mohan kumar'

# %%
age = 28
info = f"{first} {last} is {age} years old"
info
# Out:
# 'mohan kumar is 28 years old'

# %%
name[0:5]
# Out:
# 'mohan'
